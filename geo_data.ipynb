# %%
import geopandas as gpd

# Load the shapefile
shapefile_path = r'C:\Users\rishi\ml_projects\climate\hmda_boundary\hmda_boundary.shp'
gdf = gpd.read_file(shapefile_path)

# View the first few rows of the data
gdf
# Out:
#      Area   S_No    No_HH     TOT_P     TOT_M     TOT_F     P_06     M_06  \
# 0   255.0  415.0  37246.0  156067.0   79754.0   76313.0  17498.0   9151.0
# 1    42.0  254.0  81040.0  335634.0  168831.0  166803.0  34494.0  17809.0
# 2     9.0   42.0      0.0  153558.0       0.0       0.0      0.0      0.0
# 3     4.0   43.0      0.0   59070.0       0.0       0.0      0.0      0.0
# 4    13.0   44.0      0.0  442229.0       0.0       0.0      0.0      0.0
# ..    ...    ...      ...       ...       ...       ...      ...      ...
# 66   38.0  442.0  11079.0   45439.0   23338.0   22101.0   6152.0   3116.0
# 67  111.0  447.0  15143.0   60218.0   32619.0   27599.0   7968.0   4119.0
# 68  113.0  252.0   8614.0   38637.0   19222.0   19415.0   4695.0   2441.0
# 69   87.0  240.0   6020.0   25903.0   13065.0   12838.0   3252.0   1720.0
# 70  237.0  265.0   5454.0   23194.0   11665.0   11529.0   2726.0   1383.0
#
#        F_06     P_SC  ...     F_SC    P_ST    M_ST    F_ST  Shape_Leng  \
# ...

# %%
# Check the Coordinate Reference System
print(gdf.crs)

# List the columns (attributes) in the GeoDataFrame
print(gdf.columns)
# Out:
# EPSG:4326
# Index(['Area', 'S_No', 'No_HH', 'TOT_P', 'TOT_M', 'TOT_F', 'P_06', 'M_06',
#        'F_06', 'P_SC', 'M_SC', 'F_SC', 'P_ST', 'M_ST', 'F_ST', 'Shape_Leng',
#        'Shape_Area', 'Mandal_Nam', 'Dist_Name', 'N_Revenue', 'geometry'],
#       dtype='object')

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
bbox = gdf.total_bounds
print(bbox)
# Out:
# [78.00405826 16.93264351 79.04971836 17.90150706]

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to your .png file
png_path =r"C:\Users\rishi\ml_projects\climate\to_delete\waste.png"

# Open the .png file using Pillow
image = Image.open(png_path)
print(image)
# Convert the image to a NumPy array (optional, but useful for some operations)
image_array = np.array(image)

# Plot the image using matplotlib
plt.figure(figsize=(8, 8))
plt.imshow(image_array)
plt.axis('off')  # Hide axes for a cleaner look
plt.title('PNG Image')
plt.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x1500 at 0x2046C774790>

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
def plot_geotiff_image(geotiff_path, title,cmap="gray"):
    with rasterio.open(geotiff_path) as src:
        fig, ax = plt.subplots(figsize=(10, 10))
        show(src, ax=ax, title=title,cmap=cmap)
        #gdf.boundary.plot(ax=ax, edgecolor='red') 
        fig.savefig("overlayed_image.png")
        plt.show()

# Example usage

plot_geotiff_image(r"C:\Users\rishi\ml_projects\climate\to_delete\waste.png.tif", "graph","gray")
